# %% [markdown]
# # Persitent model for prediction

# %% [markdown]
# This is a basic implementation of building and training a model to make predictions.
# - Once in a while we build and train our model and save it in a file.
#
# - Next time when we make predictions we simply load our model ( which is already trained ) and ask to make predictions.

# %% [markdown]
# ### Initial setup

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

pd.set_option('display.max_columns', 50)

# %%
# df = pd.read_csv('music.csv')
# df

# %% [markdown]
# ### Splitting the data

# %%
# input set
# X = df.drop(columns=['genre'])
# X

# %%
# output set
# y = df['genre']
# y

# %% [markdown]
# ### Create and train the model

# %%
# creating model instance
# model = DecisionTreeClassifier()


# train the model
# model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Store model (Persistent)

# %%
# after training the model, store the model
joblib.dump( model, 'music_predictor.csv' )
# Out:
# ['music_predictor.csv']

# %% [markdown]
# ### Load model for future use

# %% [markdown]
# Once the model is created, loading the data, creating & training the model is not necessary.
# So commenting them in this set up.

# %%
model = joblib.load('music_predictor.csv')

# %%
predictions = model.predict([ [24,0] ])
predictions
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Dance'], dtype=object)
